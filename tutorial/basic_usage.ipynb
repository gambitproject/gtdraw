# %%
from draw_tree import draw_tree, generate_tex, generate_pdf, generate_png, gambit_layout_to_ef

# %%
import pygambit as gbt

# %%
draw_tree("../games/one_card_poker.ef")

# %%
draw_tree("../games/efg/one_card_poker.efg")

# %%
g = gbt.read_efg("../games/efg/one_card_poker.efg")
draw_tree(g, output_path="../games/efg")

# %%
draw_tree("../games/efg/trust_game.efg")

# %%
g = gbt.read_efg("../games/efg/trust_game.efg")
draw_tree(g, output_path="../games/efg")

# %%
draw_tree("../games/2smp.ef")

# %%
draw_tree("../games/efg/2smp.efg")

# %%
g = gbt.read_efg("../games/efg/2smp.efg")
draw_tree(g, output_path="../games/efg")

# %%
draw_tree("../games/2s2x2x2.ef")

# %%
draw_tree("../games/efg/2s2x2x2.efg")

# %%
g = gbt.read_efg("../games/efg/2s2x2x2.efg")
draw_tree(g, output_path="../games/efg")

# %%
draw_tree("../games/cent2.ef")

# %%
draw_tree("../games/efg/cent2.efg")

# %%
g = gbt.read_efg("../games/efg/cent2.efg")
draw_tree(g, output_path="../games/efg")

# %%
draw_tree("../games/crossing.ef")

# %%
draw_tree("../games/Figure1.ef")

# %%
draw_tree("../games/MyTree1.ef")

# %%
draw_tree("../games/oldex.ef")

# %%
draw_tree("../games/x1.ef")

# %%
draw_tree("../games/efg/cross.efg")

# %%
g = gbt.read_efg("../games/efg/cross.efg")
draw_tree(g, output_path="../games/efg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 g = gbt.read_efg("../games/efg/cross.efg")
# ----> 2 draw_tree(g, output_path="../games/efg")
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1362, in draw_tree(ef_file, output_path, scale_factor, show_grid)
#    1359         ip.run_line_magic("load_ext", "jupyter_tikz")
#    1361     # Generate TikZ code and execute cell magic
# -> 1362     tikz_code = generate_tikz(ef_file, output_path=output_path, scale_factor=scale_factor, show_grid=show_grid)
#    1363     return ip.run_cell_magic("tikz", "", tikz_code)
#    1364 else:
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1281, in generate_tikz(game, output_path, scale_factor, show_grid)
#    1279 else:
#    1280     from .gambit_layout import gambit_layout_to_ef
# -> 1281     ef_file = gambit_layout_to_ef(game, output_path=output_path)
#    1284 # Step 1: Generate the tikzpicture content using ef_to_tex logic
#    1285 tikz_picture_content = ef_to_tex(ef_file, scale_factor, show_grid)
#
# File ~/projects/draw_tree/src/draw_tree/gambit_layout.py:118, in gambit_layout_to_ef(game, output_path)
#     116         ef += "payoffs "
#     117         for player in game.players:
# --> 118             ef += f"{node.outcome.__getitem__(player.label)} "
#     119     ef += "\n"
#     121 # Build the infoset lines in the .ef string
#
# AttributeError: 'NoneType' object has no attribute '__getitem__'

# %%
draw_tree("../games/efg/holdout.efg")

# %%
g = gbt.read_efg("../games/efg/holdout.efg")
draw_tree(g, output_path="../games/efg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 g = gbt.read_efg("../games/efg/holdout.efg")
# ----> 2 draw_tree(g, output_path="../games/efg")
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1362, in draw_tree(ef_file, output_path, scale_factor, show_grid)
#    1359         ip.run_line_magic("load_ext", "jupyter_tikz")
#    1361     # Generate TikZ code and execute cell magic
# -> 1362     tikz_code = generate_tikz(ef_file, output_path=output_path, scale_factor=scale_factor, show_grid=show_grid)
#    1363     return ip.run_cell_magic("tikz", "", tikz_code)
#    1364 else:
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1281, in generate_tikz(game, output_path, scale_factor, show_grid)
#    1279 else:
#    1280     from .gambit_layout import gambit_layout_to_ef
# -> 1281     ef_file = gambit_layout_to_ef(game, output_path=output_path)
#    1284 # Step 1: Generate the tikzpicture content using ef_to_tex logic
#    1285 tikz_picture_content = ef_to_tex(ef_file, scale_factor, show_grid)
#
# File ~/projects/draw_tree/src/draw_tree/gambit_layout.py:118, in gambit_layout_to_ef(game, output_path)
#     116         ef += "payoffs "
#     117         for player in game.players:
# --> 118             ef += f"{node.outcome.__getitem__(player.label)} "
#     119     ef += "\n"
#     121 # Build the infoset lines in the .ef string
#
# AttributeError: 'NoneType' object has no attribute '__getitem__'

# %%
generate_tex('../games/x1.ef')
generate_pdf('../games/x1.ef')
generate_png('../games/x1.ef')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 generate_tex('../games/x1.ef')
#       2 generate_pdf('../games/x1.ef')
#       3 generate_png('../games/x1.ef')
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1437, in generate_tex(ef_file, output_tex, scale_factor, show_grid)
#    1434         pass
#    1436 # Generate TikZ content using generate_tikz
# -> 1437 tikz_content = generate_tikz(ef_file, scale_factor, show_grid)
#    1439 # Wrap in complete LaTeX document
#    1440 latex_document = latex_wrapper(tikz_content)
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1285, in generate_tikz(game, output_path, scale_factor, show_grid)
#    1281     ef_file = gambit_layout_to_ef(game, output_path=output_path)
#    1284 # Step 1: Generate the tikzpicture content using ef_to_tex logic
# -> 1285 tikz_picture_content = ef_to_tex(ef_file, scale_factor, show_grid)
#    1287 # Step 2: Define built-in macro definitions (from macros-drawtree.tex)
#    1288 macro_definitions = [
#    1289     "\\newcommand\\chancecolor{red}",
#    1290     "\\newdimen\\ndiam",
#    (...)   1305     "\\treethickn1pt"
#    1306 ]
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1229, in ef_to_tex(ef_file, scale_factor, show_grid)
#    1227             level(words)
#    1228         elif words[0] == "iset":
# -> 1229             isetgen(words)
#    1231 # Output nodes
#    1232 drawnodes()
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1055, in isetgen(words)
#    1053     error("No valid nodes in iset", stream0)
#    1054     return
# -> 1055 outs( iset(nodelist, radius/scale), stream0)
#    1056 # locate and print player
#    1057 if p >= 0 and playername[p]:
#
# ZeroDivisionError: float division by zero

# %%
generate_tex('../games/efg/one_card_poker.efg')
generate_pdf('../games/efg/one_card_poker.efg')
generate_png('../games/efg/one_card_poker.efg')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 generate_tex('../games/efg/one_card_poker.efg')
#       2 generate_pdf('../games/efg/one_card_poker.efg')
#       3 generate_png('../games/efg/one_card_poker.efg')
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1437, in generate_tex(ef_file, output_tex, scale_factor, show_grid)
#    1434         pass
#    1436 # Generate TikZ content using generate_tikz
# -> 1437 tikz_content = generate_tikz(ef_file, scale_factor, show_grid)
#    1439 # Wrap in complete LaTeX document
#    1440 latex_document = latex_wrapper(tikz_content)
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1285, in generate_tikz(game, output_path, scale_factor, show_grid)
#    1281     ef_file = gambit_layout_to_ef(game, output_path=output_path)
#    1284 # Step 1: Generate the tikzpicture content using ef_to_tex logic
# -> 1285 tikz_picture_content = ef_to_tex(ef_file, scale_factor, show_grid)
#    1287 # Step 2: Define built-in macro definitions (from macros-drawtree.tex)
#    1288 macro_definitions = [
#    1289     "\\newcommand\\chancecolor{red}",
#    1290     "\\newdimen\\ndiam",
#    (...)   1305     "\\treethickn1pt"
#    1306 ]
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1229, in ef_to_tex(ef_file, scale_factor, show_grid)
#    1227             level(words)
#    1228         elif words[0] == "iset":
# -> 1229             isetgen(words)
#    1231 # Output nodes
#    1232 drawnodes()
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1055, in isetgen(words)
#    1053     error("No valid nodes in iset", stream0)
#    1054     return
# -> 1055 outs( iset(nodelist, radius/scale), stream0)
#    1056 # locate and print player
#    1057 if p >= 0 and playername[p]:
#
# ZeroDivisionError: float division by zero
