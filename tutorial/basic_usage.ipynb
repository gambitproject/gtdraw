# %%
from draw_tree import draw_tree, generate_tex, generate_pdf, generate_png, gambit_layout_to_ef

# %%
import pygambit as gbt

# %%
draw_tree("../games/one_card_poker.ef")

# %%
draw_tree("../games/efg/one_card_poker.efg")

# %%
g = gbt.read_efg("../games/efg/one_card_poker.efg")
draw_tree(g, output_path="../games/efg", level_spacing=5, width_spacing=3, sublevel_spacing=4, scale_factor=0.8)

# %%
draw_tree("../games/efg/trust_game.efg")

# %%
g = gbt.read_efg("../games/efg/trust_game.efg")
draw_tree(g, output_path="../games/efg", level_spacing=2)

# %%
draw_tree("../games/2smp.ef")

# %%
draw_tree("../games/efg/2smp.efg")

# %%
g = gbt.read_efg("../games/efg/2smp.efg")
draw_tree(g, output_path="../games/efg", sublevel_spacing=1, scale_factor=0.5)

# %%
draw_tree("../games/2s2x2x2.ef")

# %%
draw_tree("../games/efg/2s2x2x2.efg")

# %%
g = gbt.read_efg("../games/efg/2s2x2x2.efg")
draw_tree(g, output_path="../games/efg", scale_factor=0.5)

# %%
draw_tree("../games/cent2.ef")

# %%
draw_tree("../games/efg/cent2.efg")

# %%
g = gbt.read_efg("../games/efg/cent2.efg")
draw_tree(g, output_path="../games/efg", scale_factor=0.4, width_spacing=4, level_spacing=10, sublevel_spacing=3)

# %%
draw_tree("../games/crossing.ef")

# %%
draw_tree("../games/Figure1.ef")

# %%
draw_tree("../games/MyTree1.ef")

# %%
draw_tree("../games/oldex.ef")

# %%
draw_tree("../games/x1.ef")

# %%
draw_tree("../games/efg/cross.efg")

# %%
g = gbt.read_efg("../games/efg/cross.efg")
draw_tree(g, output_path="../games/efg", width_spacing=4)

# %%
# draw_tree("../games/efg/holdout.efg")

# %%
g = gbt.read_efg("../games/efg/holdout.efg")
draw_tree(g, output_path="../games/efg", scale_factor=0.3)

# %%
generate_tex('../games/x1.ef')
generate_pdf('../games/x1.ef')
generate_png('../games/x1.ef')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 generate_tex('../games/x1.ef')
#       2 generate_pdf('../games/x1.ef')
#       3 generate_png('../games/x1.ef')
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1466, in generate_tex(ef_file, output_tex, scale_factor, show_grid)
#    1463         pass
#    1465 # Generate TikZ content using generate_tikz
# -> 1466 tikz_content = generate_tikz(ef_file, scale_factor, show_grid)
#    1468 # Wrap in complete LaTeX document
#    1469 latex_document = latex_wrapper(tikz_content)
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1298, in generate_tikz(game, output_path, scale_factor, level_spacing, sublevel_spacing, width_spacing, show_grid)
#    1289     ef_file = gambit_layout_to_ef(
#    1290         game,
#    1291         output_path=output_path,
#    (...)   1294         xshift_multiplier=width_spacing
#    1295     )
#    1297 # Step 1: Generate the tikzpicture content using ef_to_tex logic
# -> 1298 tikz_picture_content = ef_to_tex(ef_file, scale_factor, show_grid)
#    1300 # Step 2: Define built-in macro definitions (from macros-drawtree.tex)
#    1301 macro_definitions = [
#    1302     "\\newcommand\\chancecolor{red}",
#    1303     "\\newdimen\\ndiam",
#    (...)   1318     "\\treethickn1pt"
#    1319 ]
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1229, in ef_to_tex(ef_file, scale_factor, show_grid)
#    1227             level(words)
#    1228         elif words[0] == "iset":
# -> 1229             isetgen(words)
#    1231 # Output nodes
#    1232 drawnodes()
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1055, in isetgen(words)
#    1053     error("No valid nodes in iset", stream0)
#    1054     return
# -> 1055 outs( iset(nodelist, radius/scale), stream0)
#    1056 # locate and print player
#    1057 if p >= 0 and playername[p]:
#
# ZeroDivisionError: float division by zero

# %%
generate_tex('../games/efg/one_card_poker.efg')
generate_pdf('../games/efg/one_card_poker.efg')
generate_png('../games/efg/one_card_poker.efg')
