# %%
from draw_tree import draw_tree, generate_tex, generate_pdf, generate_png, generate_svg

# %%
draw_tree("../games/one_card_poker.ef")

# %%
draw_tree("../games/crossing.ef")

# %%
draw_tree("../games/Figure1.ef")

# %%
draw_tree("../games/MyTree1.ef")

# %%
draw_tree("../games/oldex.ef")

# %%
draw_tree("../games/x1.ef")

# %%
draw_tree("../games/x1.ef", color_scheme="gambit")

# %%
draw_tree("../games/x1.ef", color_scheme="distinctipy")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 draw_tree("../games/x1.ef", color_scheme="distinctipy")
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1845, in draw_tree(game, save_to, scale_factor, level_scaling, sublevel_scaling, width_scaling, hide_action_labels, shared_terminal_depth, show_grid, color_scheme, edge_thickness, action_label_position)
#    1843     if not jpt_loaded:
#    1844         ip.run_line_magic("load_ext", "jupyter_tikz")
# -> 1845     return ip.run_cell_magic("tikz", "", tikz_code)
#    1846 else:
#    1847     return tikz_code
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/site-packages/jupyter_tikz/jupyter_tikz.py:746, in TikZMagics.tikz(self, line, cell, local_ns)
#     744 image = None
#     745 if not self.args["no_compile"]:
# --> 746     image = self.tex_obj.run_latex(
#     747         tex_program=self.args["tex_program"],
#     748         tex_args=self.args["tex_args"],
#     749         rasterize=self.args["rasterize"],
#     750         full_err=self.args["full_err"],
#     751         keep_temp=self.args["keep_temp"],
#     752         save_tikz=self.args["save_tikz"],
#     753         save_tex=self.args["save_tex"],
#     754         save_pdf=self.args["save_pdf"],
#     755         save_image=self.args["save_image"],
#     756         dpi=self.args["dpi"],
#     757         grayscale=self.args["gray"],
#     758     )
#     759     if image is None:
#     760         return None
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/site-packages/jupyter_tikz/jupyter_tikz.py:194, in TexDocument.run_latex(self, tex_program, tex_args, rasterize, full_err, keep_temp, save_image, dpi, grayscale, save_tex, save_tikz, save_pdf)
#     191     tex_command += f" {tex_args}"
#     192 tex_command += f" {tex_path}"
# --> 194 res = self._run_command(tex_command, full_err=full_err)
#     195 if res != 0:
#     196     self._clearup_latex_garbage(keep_temp)
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/site-packages/jupyter_tikz/jupyter_tikz.py:111, in TexDocument._run_command(self, command, full_err, **kwargs)
#     109 def _run_command(self, command: str, full_err: bool = False, **kwargs) -> int:
# --> 111     result = subprocess.run(
#     112         command,
#     113         shell=True,
#     114         capture_output=True,
#     115         text=True,
#     116         check=False,
#     117         **kwargs,
#     118     )
#     119     if result.returncode != 0:
#     120         err_msg = result.stderr if result.stderr else result.stdout
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/subprocess.py:1222, in Popen.communicate(self, input, timeout)
#    1219     endtime = None
#    1221 try:
# -> 1222     stdout, stderr = self._communicate(input, endtime, timeout)
#    1223 except KeyboardInterrupt:
#    1224     # https://bugs.python.org/issue25942
#    1225     # See the detailed comment in .wait().
#    1226     if timeout is not None:
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/subprocess.py:2128, in Popen._communicate(self, input, endtime, orig_timeout)
#    2121     self._check_timeout(endtime, orig_timeout,
#    2122                         stdout, stderr,
#    2123                         skip_check_and_raise=True)
#    2124     raise RuntimeError(  # Impossible :)
#    2125         '_check_timeout(..., skip_check_and_raise=True) '
#    2126         'failed to raise TimeoutExpired.')
# -> 2128 ready = selector.select(timeout)
#    2129 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2131 # XXX Rewrite these to use non-blocking I/O on the file
#    2132 # objects; they are no longer using C stdio!
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/selectors.py:398, in _PollLikeSelector.select(self, timeout)
#     396 ready = []
#     397 try:
# --> 398     fd_event_list = self._selector.poll(timeout)
#     399 except InterruptedError:
#     400     return ready
#
# KeyboardInterrupt:

# %%
draw_tree("../games/x1.ef", color_scheme="colorblind")

# %%
generate_tex('../games/x1.ef')
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/x1.tex'

# %%
generate_tex('../games/x1.ef', save_to='custom')
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/custom.tex'

# %%
generate_pdf('../games/x1.ef')
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/x1.pdf'

# %%
generate_png('../games/x1.ef')
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/x1.png'

# %%
generate_svg("../games/x1.ef")
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/x1.svg'
