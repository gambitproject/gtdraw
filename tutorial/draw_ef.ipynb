# %%
from gtdraw import draw, tex, pdf, png, svg

# %%
draw("../games/one_card_poker.ef")

# %%
draw("../games/crossing.ef")

# %%
draw("../games/Figure1.ef")

# %%
draw("../games/MyTree1.ef")

# %%
draw("../games/oldex.ef")

# %%
draw("../games/x1.ef")

# %%
draw("../games/x1.ef", color_scheme="gambit")

# %%
draw("../games/x1.ef", color_scheme="distinctipy")

# %%
draw("../games/x1.ef", color_scheme="colorblind")

# %%
tex('../games/x1.ef')
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/x1.tex'

# %%
tex('../games/x1.ef', save_to='custom')
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/custom.tex'

# %%
pdf('../games/x1.ef')
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/x1.pdf'

# %%
png('../games/x1.ef')
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/x1.png'

# %%
svg("../games/x1.ef")
# Out:
# '/Users/echalstrey/projects/draw_tree/tutorial/x1.svg'
