# %%
import pygambit as gbt
from draw_tree import generate_tex, generate_pdf, generate_png

# %%
g = gbt.read_efg("../games/efg/one_card_poker.efg")

# %%
generate_png(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 generate_png(g)
#
# File ~/projects/draw_tree/src/draw_tree/core.py:1867, in generate_png(ef_file, output_png, scale_factor, show_grid, dpi, cleanup)
#    1865 # Determine output filename
#    1866 if output_png is None:
# -> 1867     ef_path = Path(ef_file)
#    1868     output_png = ef_path.with_suffix('.png').name
#    1870 # Step 1: Generate PDF first
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/pathlib/_local.py:503, in Path.__init__(self, *args, **kwargs)
#     500     msg = ("support for supplying keyword arguments to pathlib.PurePath "
#     501            "is deprecated and scheduled for removal in Python {remove}")
#     502     warnings._deprecated("pathlib.PurePath(**kwargs)", msg, remove=(3, 14))
# --> 503 super().__init__(*args)
#
# File ~/anaconda3/envs/gambitvenv313/lib/python3.13/pathlib/_local.py:132, in PurePath.__init__(self, *args)
#     130             path = arg
#     131         if not isinstance(path, str):
# --> 132             raise TypeError(
#     133                 "argument should be a str or an os.PathLike "
#     134                 "object where __fspath__ returns a str, "
#     135                 f"not {type(path).__name__!r}")
#     136         paths.append(path)
#     137 # Avoid calling super().__init__, as an optimisation
#
# TypeError: argument should be a str or an os.PathLike object where __fspath__ returns a str, not 'Game'

# %%
generate_tex(g)

# %%
generate_pdf(g)
